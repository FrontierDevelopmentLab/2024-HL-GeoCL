# %% [markdown]
# # HUX tutorial

# %% [markdown]
# [1] Riley P and Lionello R (2011) "Mapping Solar Wind Streams from the Sun to 1 AU: A Comparison of Techniques". Solar Phys.270, 575–592.
#
# [2] Riley P and Issan O (2021) "Using a Heliospheric Upwinding eXtrapolation Technique to Magnetically Connect Different Regions of the Heliosphere". Front. Phys. 9:679497.
#
# [3] Issan O and Riley P (2022). Theoretical Refinements to the Heliospheric Upwind eXtrapolation Technique and Application to in-situ Measurements. Frontiers in Astronomy and Space Sciences, 8:795323.

# %%
# pip install heliopy==0.15.3 & h5py==3.7.0 & h5netcdf==1.0.0 & cdflib==1.0.0 & mpl-animators==1.0.0
# & xarray==2024.6.0 & astropy==24.1
import sys, os
sys.path.append(os.path.abspath(os.path.join('..')))

# %%
import numpy as np 
import datetime as dt 
import scipy
from heliopy.data import omni
import heliopy.data.spice as spicedata
from astropy.coordinates import SkyCoord
import astropy.units as u

from hux_code import *

# %%
import matplotlib.pyplot as plt
import matplotlib
from mycolorpy import colorlist as mcp

font = {'family' : 'serif',
        'size'   : 14}

matplotlib.rc('font', **font)
matplotlib.rc('xtick', labelsize=14) 
matplotlib.rc('ytick', labelsize=14)

# %% [markdown]
# # Read in OMNI data

# %%
# CR2286
starttime = dt.datetime(year=2024, month=6, day=2)
endtime =  dt.datetime(year=2024, month=6, day=29)

# %%
omni_data = omni.h0_mrg1hr(starttime, endtime)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 omni_data = omni.h0_mrg1hr(starttime, endtime)
#
# File /opt/anaconda3/envs/gp/lib/python3.10/site-packages/heliopy/data/omni.py:31, in h0_mrg1hr(starttime, endtime)
#      29 def h0_mrg1hr(starttime, endtime):
#      30     identifier = 'OMNI2_H0_MRG1HR'
# ---> 31     return _omni(starttime, endtime, identifier, warn_missing_units=False,
#      32                  intervals='yearly')
#
# File /opt/anaconda3/envs/gp/lib/python3.10/site-packages/heliopy/data/omni.py:25, in _omni(starttime, endtime, identifier, intervals, warn_missing_units)
#      23 elif intervals == 'yearly':
#      24     dl.intervals = dl.intervals_yearly
# ---> 25 return dl.load(starttime, endtime)
#
# File /opt/anaconda3/envs/gp/lib/python3.10/site-packages/heliopy/data/util.py:92, in Downloader.load(self, starttime, endtime)
#      89         continue
#      91 try:
# ---> 92     data.append(self.load_local_file(interval))
#      93 except CDFEmptyError:
#      94     continue
#
# File /opt/anaconda3/envs/gp/lib/python3.10/site-packages/heliopy/data/cdasrest.py:105, in CDASDwonloader.load_local_file(self, interval)
#     103 local_path = self.local_path(interval)
#     104 cdf = util._load_cdf(local_path)
# --> 105 return util.cdf2df(cdf, index_key='Epoch',
#     106                    badvalues=self.badvalues)
#
# File /opt/anaconda3/envs/gp/lib/python3.10/site-packages/heliopy/data/util.py:762, in cdf2df(cdf, index_key, dtimeindex, badvalues, ignore, include)
#     760 # Extract index values
#     761 index_info = cdf.varinq(index_key)
# --> 762 if index_info['Last_Rec'] == -1:
#     763     raise CDFEmptyError('No records present in CDF file')
#     765 index = cdf.varget(index_key)
#
# TypeError: 'VDRInfo' object is not subscriptable

# %%
earth_traj = spice.Trajectory('Earth')
earth_traj.generate_positions(times=omni_data.index, observing_body='Sun', frame='IAU_SUN')
earth_coords = earth_traj.coords
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 earth_traj = spice.Trajectory('Earth')
#       2 earth_traj.generate_positions(times=omni_data.index, observing_body='Sun', frame='IAU_SUN')
#       3 earth_coords = earth_traj.coords
#
# NameError: name 'spice' is not defined

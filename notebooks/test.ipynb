# %%
# %reload_ext autoreload
# %autoreload 2
import re
import urllib
from bs4 import BeautifulSoup
from geocloak.datautilus import La

# %%
ind = day_list[-1].find("_s")

# %%
timstamp = day_list[-1][ind+2:ind+16]
timstamp
# Out:
# '20240709000000'

# %%
p
# Out:
# '20240709'

# %%
day_list[-1]
# Out:
# 'oe_f1m_dscovr_s20240709000000_e20240709235959_p20240710022232_pub.nc.gz'
